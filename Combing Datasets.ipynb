# %%
import pandas as pd

# %%
dd = pd.read_csv('district_data.csv')

# %%
dd
# Out:
#       Unnamed: 0                                        School Name  \
# 0              0            Lower East Side Preparatory High School
# 1              1                         East Side Community School
# 2              2                            Marta Valle High School
# 3              3                             Ps 15 Roberto Clemente
# 4              4                                   Ps 19 Asher Levy
# ...          ...                                                ...
# 1509        1509  Bushwick Leaders High School For Academic Exce...
# 1510        1510                     Bushwick Community High School
# 1511        1511               Academy For Environmental Leadership
# 1512        1512        Brooklyn School For Math And Research (The)
# 1513        1513      Evergreen Middle School For Urban Exploration
#
#      Enrollment  Student-Teacher Ratio Free-Reduced Lunch  DISTRICT
# 0           500                   15.6              76.8%         1
# ...

# %%
dd.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dd
# Out:
#                                             School Name Enrollment  \
# 0               Lower East Side Preparatory High School        500
# 1                            East Side Community School        678
# 2                               Marta Valle High School        149
# 3                                Ps 15 Roberto Clemente        191
# 4                                      Ps 19 Asher Levy        258
# ...                                                 ...        ...
# 1509  Bushwick Leaders High School For Academic Exce...        280
# 1510                     Bushwick Community High School        202
# 1511               Academy For Environmental Leadership        272
# 1512        Brooklyn School For Math And Research (The)        272
# 1513      Evergreen Middle School For Urban Exploration        345
#
#       Student-Teacher Ratio Free-Reduced Lunch  DISTRICT
# 0                      15.6              76.8%         1
# ...

# %%
dd['School Name'] = dd['School Name'].str.lower()

# %%
dd
# Out:
#                                             School Name Enrollment  \
# 0               lower east side preparatory high school        500
# 1                            east side community school        678
# 2                               marta valle high school        149
# 3                                ps 15 roberto clemente        191
# 4                                      ps 19 asher levy        258
# ...                                                 ...        ...
# 1509  bushwick leaders high school for academic exce...        280
# 1510                     bushwick community high school        202
# 1511               academy for environmental leadership        272
# 1512        brooklyn school for math and research (the)        272
# 1513      evergreen middle school for urban exploration        345
#
#       Student-Teacher Ratio Free-Reduced Lunch  DISTRICT
# 0                      15.6              76.8%         1
# ...

# %%
year_data = pd.read_csv('2006-2007_School_Progress_Report.csv')

# %%
year_data['SCHOOL'] = year_data['SCHOOL'].str.lower()

# %%
year_data.drop(['DBN', 'SCHOOL SUPPORT ORGANIZATION/NETWORK', 'PROGRESS REPORT TYPE'], axis=1, inplace=True)

# %%
year_data
# Out:
#       DISTRICT                                        SCHOOL  \
# 0            1                       ps 015 roberto clemente
# 1            1                             ps 019 asher levy
# 2            1                            ps 020 anna silver
# 3            1                   ps 034 franklin d roosevelt
# 4            1                       ps 063 william mckinley
# ...        ...                                           ...
# 1257        84       future leaders institute charter school
# 1258        84  peninsula preparatory academy charter school
# 1259        84                the renaissance charter school
# 1260        84           the bronx lighthouse charter school
# 1261        84                   kipp academy charter school
#
#           SCHOOL LEVEL*  PEER INDEX*  GRADE OVERALL SCORE  \
# 0     Elementary School        75.60      B         52.31
# 1     Elementary School        59.25      B         51.24
# ...
